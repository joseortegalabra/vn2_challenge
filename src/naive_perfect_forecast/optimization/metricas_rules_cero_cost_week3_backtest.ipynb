# %% [markdown]
# ### ANALIZAR MÉTRICAS OBTENIDAS DE CÁLCULO DE COSTOS - BACKTEST

# %%
import pandas as pd
import numpy as np

from utils.utils import read_processed_data, set_root_path
from mlforecast import MLForecast
import lightgbm as lgb

from mlforecast.lag_transforms import (
    RollingMean,
    SeasonalRollingMean,
)
from sklearn.metrics import mean_absolute_error

import seaborn as sns
import matplotlib.pyplot as plt

# %%
# set root repo
set_root_path()
# Out:
# root path: /Users/joseortega/Documents/GitHub/vn2_challenge

# %% [markdown]
# ### 1. leer tablas a analizar

# %%
# leer output backtest estrategia optimizar costos
folder_output = "data/submission/backtest"
next_data_state_backtest = pd.read_csv(
    f"{folder_output}/next_data_state_backtest.csv"
)

# %%
next_data_state_backtest.head()
# Out:
#    Unnamed: 0 unique_id  Store  Product  Start Inventory  Sales  Missed Sales  \
# 0           0     0-126      0      126                0      0           6.0
# 1           1     0-182      0      182                0      0           1.0
# 2           2     1-124      1      124                0      0           6.0
# 3           3     2-124      2      124                0      0          18.0
# 4           4     2-126      2      126                0      0           7.0
#
#    End Inventory  In Transit W+1  In Transit W+2  Holding Cost  Shortage Cost  \
# 0              0               0               5           0.0            6.0
# 1              0               0               1           0.0            1.0
# 2              0               0               6           0.0            6.0
# 3              0               0              11           0.0           18.0
# 4              0               0               5           0.0            7.0
#
#    Cumulative Holding Cost  Cumulative Shortage Cost  fcst_w1  fcst_w2  \
# 0                      0.0                       6.0      4.0      4.0
# 1                      0.0                       1.0      1.0      1.0
# 2                      0.0                       6.0      4.0      4.0
# 3                      0.0                      18.0      9.0     10.0
# 4                      0.0                       7.0      3.0      3.0
#
#    fcst_w3 week0_update
# 0      3.0   2023-06-05
# 1      1.0   2023-06-05
# 2      4.0   2023-06-05
# 3      8.0   2023-06-05
# 4      3.0   2023-06-05

# %% [markdown]
# ### 2. Resumen costos - en la última ejecución del backtest - resumen global

# %%
# obtener última fecha de actualización
last_week_backtest = next_data_state_backtest["week0_update"].max()
last_week_backtest
# Out:
# '2024-03-18'

# %%
# filtrar para tener la última actualización
last_update_backtest_costs = next_data_state_backtest[next_data_state_backtest["week0_update"] == last_week_backtest]

# crear columna auxiliar total de ambos costos
last_update_backtest_costs.loc[:, "Cumulative Holding+Shortage Cost"] = last_update_backtest_costs["Cumulative Holding Cost"] + last_update_backtest_costs["Cumulative Shortage Cost"]

last_update_backtest_costs.head(3)
# Out:
# /var/folders/fx/0kx46vn52sg544t8x3s4hdl00000gn/T/ipykernel_56439/1466740726.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_update_backtest_costs.loc[:, "Cumulative Holding+Shortage Cost"] = last_update_backtest_costs["Cumulative Holding Cost"] + last_update_backtest_costs["Cumulative Shortage Cost"]
#        Unnamed: 0 unique_id  Store  Product  Start Inventory  Sales  \
# 24559           0     0-126      0      126               22      0
# 24560           1     0-182      0      182                0      0
# 24561           2     1-124      1      124                9      7
#
#        Missed Sales  End Inventory  In Transit W+1  In Transit W+2  \
# 24559           0.0             22               2               2
# 24560           3.0              0               1               1
# 24561           0.0              2               2               2
#
#        Holding Cost  Shortage Cost  Cumulative Holding Cost  \
# 24559           4.4            0.0                     45.6
# 24560           0.0            3.0                      5.6
# 24561           0.4            0.0                      6.6
#
#        Cumulative Shortage Cost  fcst_w1  fcst_w2  fcst_w3 week0_update  \
# 24559                      36.0      1.0      2.0      1.0   2024-03-18
# 24560                      18.0      1.0      1.0      1.0   2024-03-18
# 24561                     123.0      9.0      8.0      9.0   2024-03-18
#
#        Cumulative Holding+Shortage Cost
# 24559                              81.6
# 24560                              23.6
# 24561                             129.6

# %%
# SUMAR LOS COSTOS A NIVEL "UNIQUE_ID" para tener los costos totales
cum_holding_costs = last_update_backtest_costs["Cumulative Holding Cost"].sum()
cum_shortage_costs = last_update_backtest_costs["Cumulative Shortage Cost"].sum()
cum_total_costs = last_update_backtest_costs["Cumulative Holding+Shortage Cost"].sum()

print("cum_holding_costs: ", cum_holding_costs)
print("cum_shortage_costs: ", cum_shortage_costs)
print("cum_total_costs: ", cum_total_costs)
# Out:
# cum_holding_costs:  12133.800000000003
# cum_shortage_costs:  32123.0
# cum_total_costs:  44256.8

# %%
# valores usando directamente el forecast
#cum_holding_costs:  4402.6
#cum_shortage_costs:  45714.0
#cum_total_costs:  50116.6

# valores usando el forecast + holgura basada en el MAE de backtest
#cum_holding_costs:  12133.800000000003
#cum_shortage_costs:  32123.0
#cum_total_costs:  44256.8

# OJO: agregando la holgura aumentó el costo de holding pero disminuyó el de cum_shortage_costs

# %% [markdown]
# ### 2. Resumen costos - en la última ejecución del backtest - series individualmente

# %%
# obtener última fecha de actualización
last_week_backtest = next_data_state_backtest["week0_update"].max()
last_week_backtest
# Out:
# '2024-03-18'

# %%
# filtrar para tener la última actualización
last_update_backtest_costs = next_data_state_backtest[next_data_state_backtest["week0_update"] == last_week_backtest]

# crear columna auxiliar total de ambos costos
last_update_backtest_costs.loc[:, "Cumulative Holding+Shortage Cost"] = last_update_backtest_costs["Cumulative Holding Cost"] + last_update_backtest_costs["Cumulative Shortage Cost"]

# ordenar por costos acumulado de mayor a menor costo
last_update_backtest_costs = last_update_backtest_costs.sort_values("Cumulative Holding+Shortage Cost", ascending=False)
# Out:
# /var/folders/fx/0kx46vn52sg544t8x3s4hdl00000gn/T/ipykernel_56439/427351972.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   last_update_backtest_costs.loc[:, "Cumulative Holding+Shortage Cost"] = last_update_backtest_costs["Cumulative Holding Cost"] + last_update_backtest_costs["Cumulative Shortage Cost"]

# %%
last_update_backtest_costs
# Out:
#        Unnamed: 0 unique_id  Store  Product  Start Inventory  Sales  \
# 24760         201     61-23     61       23               57     57
# 24836         277    61-124     61      124               25     25
# 25113         554    63-124     63      124               24     24
# 24692         133    60-125     60      125               53     53
# 24653          94     60-23     60       23               71     30
# ...           ...       ...    ...      ...              ...    ...
# 24923         364    61-249     61      249                2      2
# 24701         142    60-166     60      166                0      0
# 25088         529    62-296     62      296                1      1
# 24823         264    61-101     61      101                1      1
# 25048         489    62-191     62      191                1      0
#
#        Missed Sales  End Inventory  In Transit W+1  In Transit W+2  \
# 24760          11.0              0              50              57
# 24836          34.0              0              80              54
# 25113          45.0              0             106              28
# 24692           5.0              0              56              19
# 24653           0.0             41              38              38
# ...             ...            ...             ...             ...
# 24923           0.0              0               0               0
# 24701           0.0              0               0               1
# 25088           0.0              0               1               0
# 24823           0.0              0               0               1
# 25048           0.0              1               0               1
#
#        Holding Cost  Shortage Cost  Cumulative Holding Cost  \
# 24760           0.0           11.0                    463.2
# 24836           0.0           34.0                     47.4
# 25113           0.0           45.0                     99.4
# 24692           0.0            5.0                     90.8
# 24653           8.2            0.0                    497.6
# ...             ...            ...                      ...
# 24923           0.0            0.0                      5.0
# 24701           0.0            0.0                      6.8
# 25088           0.0            0.0                      5.8
# 24823           0.0            0.0                      3.0
# 25048           0.2            0.0                      5.4
#
#        Cumulative Shortage Cost  fcst_w1  fcst_w2  fcst_w3 week0_update  \
# 24760                    1470.0     62.0     91.0     80.0   2024-03-18
# 24836                    1852.0     66.0     81.0     78.0   2024-03-18
# 25113                    1286.0     72.0     81.0     77.0   2024-03-18
# 24692                    1211.0     72.0     71.0     62.0   2024-03-18
# 24653                     718.0     46.0     35.0     50.0   2024-03-18
# ...                         ...      ...      ...      ...          ...
# 24923                       7.0      0.0      1.0      1.0   2024-03-18
# 24701                       5.0      0.0      1.0      1.0   2024-03-18
# 25088                       6.0      0.0      1.0      1.0   2024-03-18
# 24823                       7.0      0.0      1.0      1.0   2024-03-18
# 25048                       4.0      0.0      1.0      1.0   2024-03-18
#
#        Cumulative Holding+Shortage Cost
# 24760                            1933.2
# 24836                            1899.4
# 25113                            1385.4
# 24692                            1301.8
# 24653                            1215.6
# ...                                 ...
# 24923                              12.0
# 24701                              11.8
# 25088                              11.8
# 24823                              10.0
# 25048                               9.4
#
# [599 rows x 19 columns]

# %%
last_update_backtest_costs.head(20)
# Out:
#        Unnamed: 0 unique_id  Store  Product  Start Inventory  Sales  \
# 24760         201     61-23     61       23               57     57
# 24836         277    61-124     61      124               25     25
# 25113         554    63-124     63      124               24     24
# 24692         133    60-125     60      125               53     53
# 24653          94     60-23     60       23               71     30
# 25091         532     63-23     63       23              100     73
# 24977         418     62-23     62       23               48     12
# 25145         586     64-17     64       17               49     38
# 25148         589     64-23     64       23               28     21
# 24781         222     61-48     61       48               12     12
# 24780         221     61-47     61       47               12     12
# 25124         565    63-186     63      186               13     13
# 24598          39     28-17     28       17               16     16
# 24585          26     19-17     19       17                5      5
# 24572          13     9-124      9      124               10     10
# 24623          64     45-17     45       17               15     10
# 24693         134    60-126     60      126               25      4
# 24586          27    19-103     19      103               65      0
# 24837         278    61-126     61      126               84     20
# 24621          62     44-17     44       17               10     10
#
#        Missed Sales  End Inventory  In Transit W+1  In Transit W+2  \
# 24760          11.0              0              50              57
# 24836          34.0              0              80              54
# 25113          45.0              0             106              28
# 24692           5.0              0              56              19
# 24653           0.0             41              38              38
# 25091           0.0             27              35              35
# 24977           0.0             36              33              33
# 25145           0.0             11              27              13
# 25148           0.0              7              20              20
# 24781          11.0              0              12              15
# 24780          11.0              0              12              14
# 25124           3.0              0               8               8
# 24598           2.0              0               6               6
# 24585          20.0              0              23               4
# 24572           5.0              0              20               4
# 24623           0.0              5               4               4
# 24693           0.0             21               7               7
# 24586           0.0             65               5               5
# 24837           0.0             64              10              10
# 24621           2.0              0               3               3
#
#        Holding Cost  Shortage Cost  Cumulative Holding Cost  \
# 24760           0.0           11.0                    463.2
# 24836           0.0           34.0                     47.4
# 25113           0.0           45.0                     99.4
# 24692           0.0            5.0                     90.8
# 24653           8.2            0.0                    497.6
# 25091           5.4            0.0                    293.4
# 24977           7.2            0.0                    340.0
# 25145           2.2            0.0                     47.4
# 25148           1.4            0.0                    294.8
# 24781           0.0           11.0                     38.8
# 24780           0.0           11.0                     50.0
# 25124           0.0            3.0                    137.6
# 24598           0.0            2.0                     26.6
# 24585           0.0           20.0                     19.8
# 24572           0.0            5.0                      7.2
# 24623           1.0            0.0                      9.2
# 24693           4.2            0.0                     75.8
# 24586          13.0            0.0                    259.4
# 24837          12.8            0.0                    186.6
# 24621           0.0            2.0                     15.0
#
#        Cumulative Shortage Cost  fcst_w1  fcst_w2  fcst_w3 week0_update  \
# 24760                    1470.0     62.0     91.0     80.0   2024-03-18
# 24836                    1852.0     66.0     81.0     78.0   2024-03-18
# 25113                    1286.0     72.0     81.0     77.0   2024-03-18
# 24692                    1211.0     72.0     71.0     62.0   2024-03-18
# 24653                     718.0     46.0     35.0     50.0   2024-03-18
# 25091                     900.0     36.0     38.0     26.0   2024-03-18
# 24977                     810.0     40.0     43.0     52.0   2024-03-18
# 25145                     841.0     56.0     47.0     58.0   2024-03-18
# 25148                     377.0     26.0     33.0     39.0   2024-03-18
# 24781                     504.0     22.0     19.0     20.0   2024-03-18
# 24780                     453.0     28.0     20.0     18.0   2024-03-18
# 25124                     253.0     16.0     15.0     15.0   2024-03-18
# 24598                     356.0     18.0     19.0     18.0   2024-03-18
# 24585                     330.0     15.0     17.0     16.0   2024-03-18
# 24572                     310.0     14.0     17.0     16.0   2024-03-18
# 24623                     305.0     16.0     14.0     14.0   2024-03-18
# 24693                     210.0      6.0      6.0      8.0   2024-03-18
# 24586                      25.0      2.0      3.0      4.0   2024-03-18
# 24837                      93.0      5.0      6.0      7.0   2024-03-18
# 24621                     251.0     11.0     12.0     10.0   2024-03-18
#
#        Cumulative Holding+Shortage Cost
# 24760                            1933.2
# 24836                            1899.4
# 25113                            1385.4
# 24692                            1301.8
# 24653                            1215.6
# 25091                            1193.4
# 24977                            1150.0
# 25145                             888.4
# 25148                             671.8
# 24781                             542.8
# 24780                             503.0
# 25124                             390.6
# 24598                             382.6
# 24585                             349.8
# 24572                             317.2
# 24623                             314.2
# 24693                             285.8
# 24586                             284.4
# 24837                             279.6
# 24621                             266.0

# %% [markdown]
# ### 3. Revisar todas las ejecuciones para una serie en particular

# %%
# param - serie a filtrar
unique_id_filter = "61-23"

# %%
# filtrar por la serie de interés
next_data_state_backtest[next_data_state_backtest["unique_id"] == unique_id_filter]
# Out:
#        Unnamed: 0 unique_id  Store  Product  Start Inventory  Sales  \
# 201           201     61-23     61       23                0      0
# 800           201     61-23     61       23                0      0
# 1399          201     61-23     61       23               74     24
# 1998          201     61-23     61       23              151     12
# 2597          201     61-23     61       23              189     29
# 3196          201     61-23     61       23              210     17
# 3795          201     61-23     61       23              243     60
# 4394          201     61-23     61       23              233    101
# 4993          201     61-23     61       23              182     78
# 5592          201     61-23     61       23              154     97
# 6191          201     61-23     61       23              107     43
# 6790          201     61-23     61       23              114     95
# 7389          201     61-23     61       23               69     46
# 7988          201     61-23     61       23               73     71
# 8587          201     61-23     61       23               52     52
# 9186          201     61-23     61       23               50     50
# 9785          201     61-23     61       23               67     67
# 10384         201     61-23     61       23               50     50
# 10983         201     61-23     61       23               50     20
# 11582         201     61-23     61       23               80     80
# 12181         201     61-23     61       23               50     50
# 12780         201     61-23     61       23               50     35
# 13379         201     61-23     61       23              250    250
# 13978         201     61-23     61       23               80     80
# 14577         201     61-23     61       23               50     50
# 15176         201     61-23     61       23               50     50
# 15775         201     61-23     61       23              242    194
# 16374         201     61-23     61       23               98     98
# 16973         201     61-23     61       23               50     50
# 17572         201     61-23     61       23              131     65
# 18171         201     61-23     61       23              249     39
# 18770         201     61-23     61       23              260     36
# 19369         201     61-23     61       23              274     48
# 19968         201     61-23     61       23              276     29
# 20567         201     61-23     61       23              297    180
# 21166         201     61-23     61       23              167    165
# 21765         201     61-23     61       23               52     52
# 22364         201     61-23     61       23               50     50
# 22963         201     61-23     61       23               79     78
# 23562         201     61-23     61       23               51     47
# 24161         201     61-23     61       23               54     54
# 24760         201     61-23     61       23               57     57
#
#        Missed Sales  End Inventory  In Transit W+1  In Transit W+2  \
# 201           104.0              0               0              74
# 800            25.0              0              74             101
# 1399            0.0             50             101              50
# 1998            0.0            139              50              50
# 2597            0.0            160              50              50
# 3196            0.0            193              50              50
# 3795            0.0            183              50              50
# 4394            0.0            132              50              50
# 4993            0.0            104              50              50
# 5592            0.0             57              50              50
# 6191            0.0             64              50              50
# 6790            0.0             19              50              50
# 7389            0.0             23              50              50
# 7988            0.0              2              50              50
# 8587           26.0              0              50              67
# 9186           64.0              0              67              50
# 9785           89.0              0              50              50
# 10384          27.0              0              50              50
# 10983           0.0             30              50              50
# 11582          30.0              0              50              50
# 12181          41.0              0              50             235
# 12780           0.0             15             235              80
# 13379           9.0              0              80              50
# 13978         172.0              0              50              50
# 14577         120.0              0              50             242
# 15176         350.0              0             242              50
# 15775           0.0             48              50              50
# 16374         235.0              0              50             131
# 16973          51.0              0             131             183
# 17572           0.0             66             183              50
# 18171           0.0            210              50              50
# 18770           0.0            224              50              50
# 19369           0.0            226              50              50
# 19968           0.0            247              50              50
# 20567           0.0            117              50              50
# 21166           0.0              2              50              50
# 21765          47.0              0              50              79
# 22364          42.0              0              79              50
# 22963           0.0              1              50              50
# 23562           0.0              4              50              57
# 24161          27.0              0              57              50
# 24760          11.0              0              50              57
#
#        Holding Cost  Shortage Cost  Cumulative Holding Cost  \
# 201             0.0          104.0                      0.0
# 800             0.0           25.0                      0.0
# 1399           10.0            0.0                     10.0
# 1998           27.8            0.0                     37.8
# 2597           32.0            0.0                     69.8
# 3196           38.6            0.0                    108.4
# 3795           36.6            0.0                    145.0
# 4394           26.4            0.0                    171.4
# 4993           20.8            0.0                    192.2
# 5592           11.4            0.0                    203.6
# 6191           12.8            0.0                    216.4
# 6790            3.8            0.0                    220.2
# 7389            4.6            0.0                    224.8
# 7988            0.4            0.0                    225.2
# 8587            0.0           26.0                    225.2
# 9186            0.0           64.0                    225.2
# 9785            0.0           89.0                    225.2
# 10384           0.0           27.0                    225.2
# 10983           6.0            0.0                    231.2
# 11582           0.0           30.0                    231.2
# 12181           0.0           41.0                    231.2
# 12780           3.0            0.0                    234.2
# 13379           0.0            9.0                    234.2
# 13978           0.0          172.0                    234.2
# 14577           0.0          120.0                    234.2
# 15176           0.0          350.0                    234.2
# 15775           9.6            0.0                    243.8
# 16374           0.0          235.0                    243.8
# 16973           0.0           51.0                    243.8
# 17572          13.2            0.0                    257.0
# 18171          42.0            0.0                    299.0
# 18770          44.8            0.0                    343.8
# 19369          45.2            0.0                    389.0
# 19968          49.4            0.0                    438.4
# 20567          23.4            0.0                    461.8
# 21166           0.4            0.0                    462.2
# 21765           0.0           47.0                    462.2
# 22364           0.0           42.0                    462.2
# 22963           0.2            0.0                    462.4
# 23562           0.8            0.0                    463.2
# 24161           0.0           27.0                    463.2
# 24760           0.0           11.0                    463.2
#
#        Cumulative Shortage Cost  fcst_w1  fcst_w2  fcst_w3 week0_update
# 201                       104.0     10.0     28.0     24.0   2023-06-05
# 800                       129.0     82.0     59.0     66.0   2023-06-12
# 1399                      129.0     36.0     33.0     50.0   2023-06-19
# 1998                      129.0     42.0     36.0     39.0   2023-06-26
# 2597                      129.0     44.0     52.0     64.0   2023-07-03
# 3196                      129.0     45.0     54.0     73.0   2023-07-10
# 3795                      129.0     48.0     76.0     72.0   2023-07-17
# 4394                      129.0     70.0     71.0     88.0   2023-07-24
# 4993                      129.0     86.0     85.0     78.0   2023-07-31
# 5592                      129.0     72.0     85.0     59.0   2023-08-07
# 6191                      129.0    120.0     72.0     71.0   2023-08-14
# 6790                      129.0     40.0     30.0     48.0   2023-08-21
# 7389                      129.0    106.0     94.0     72.0   2023-08-28
# 7988                      129.0     68.0     60.0     84.0   2023-09-04
# 8587                      155.0     66.0     83.0     88.0   2023-09-11
# 9186                      219.0     71.0     73.0     70.0   2023-09-18
# 9785                      308.0    114.0     67.0     47.0   2023-09-25
# 10384                     335.0     85.0     62.0     56.0   2023-10-02
# 10983                     335.0     54.0     42.0     87.0   2023-10-09
# 11582                     365.0     29.0     50.0     74.0   2023-10-16
# 12181                     406.0     86.0    166.0    185.0   2023-10-23
# 12780                     406.0    171.0    208.0    157.0   2023-10-30
# 13379                     415.0    129.0    168.0     98.0   2023-11-06
# 13978                     587.0    179.0     67.0    134.0   2023-11-13
# 14577                     707.0     95.0    137.0    205.0   2023-11-20
# 15176                    1057.0    142.0    183.0    139.0   2023-11-27
# 15775                    1057.0    236.0    192.0    175.0   2023-12-04
# 16374                    1292.0    161.0    181.0    146.0   2023-12-11
# 16973                    1343.0    205.0    202.0    162.0   2023-12-18
# 17572                    1343.0    132.0     92.0     52.0   2023-12-25
# 18171                    1343.0     77.0     49.0     44.0   2024-01-01
# 18770                    1343.0     18.0     23.0     18.0   2024-01-08
# 19369                    1343.0     19.0     14.0     38.0   2024-01-15
# 19968                    1343.0     26.0     54.0     40.0   2024-01-22
# 20567                    1343.0     47.0     46.0     34.0   2024-01-29
# 21166                    1343.0     91.0     73.0     58.0   2024-02-05
# 21765                    1390.0    128.0    104.0     79.0   2024-02-12
# 22364                    1432.0     84.0     82.0     97.0   2024-02-19
# 22963                    1432.0     74.0     84.0     77.0   2024-02-26
# 23562                    1432.0     93.0     78.0     81.0   2024-03-04
# 24161                    1459.0     52.0     47.0     57.0   2024-03-11
# 24760                    1470.0     62.0     91.0     80.0   2024-03-18
